# %%
# %pip install dbtunnel[gradio] aiohttp
# Out:
# Collecting dbtunnel[gradio]
#   Obtaining dependency information for dbtunnel[gradio] from https://files.pythonhosted.org/packages/66/d1/90c10be2d61c1a827dc8b051342ea523e64978da094aaa1ffe74904967d9/dbtunnel-0.16.0-py3-none-any.whl.metadata
#   Downloading dbtunnel-0.16.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/9f/a7/05a48c7c0a7a80a5591b1203bf1b64ca2ed6a2050af918d09c05852dc42b/aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.11/site-packages (from dbtunnel[gradio]) (1.5.6)
# Requirement already satisfied: databricks-sdk>=0.18.0 in /databricks/python3/lib/python3.11/site-packages (from dbtunnel[gradio]) (0.20.0)
# Collecting gradio==3.50.2 (from dbtunnel[gradio])
#   Obtaining dependency information for gradio==3.50.2 from https://files.pythonhosted.org/packages/bd/ea/ca6506e4da9b5338da3bfdd6115dc1c90ffd58c1ec50ca2792b84a7b4bdb/gradio-3.50.2-py3-none-any.whl.metadata
#   Downloading gradio-3.50.2-py3-none-any.whl.metadata (17 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for aiofiles<24.0,>=22.0 from https://files.pythonhosted.org/packages/c5/19/5af6804c4cc0fed83f47bff6e413a98a36618e7d40185cd36e69737f3b0e/aiofiles-23.2.1-py3-none-any.whl.metadata
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting altair<6.0,>=4.2.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for altair<6.0,>=4.2.0 from https://files.pythonhosted.org/packages/9b/52/4a86a4fa1cc2aae79137cc9510b7080c3e5aede2310d14fae5486feec7f7/altair-5.4.1-py3-none-any.whl.metadata
#   Downloading altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting fastapi (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for fastapi from https://files.pythonhosted.org/packages/57/95/4c5b79e7ca1f7b372d16a32cad7c9cc6c3c899200bed8f45739f4415cfae/fastapi-0.115.3-py3-none-any.whl.metadata
#   Downloading fastapi-0.115.3-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for ffmpy from https://files.pythonhosted.org/packages/ff/1e/db99aa669eee301966bc6c997d60a0240f9cecae63f044b2e5a5310e4bf7/ffmpy-0.4.0-py3-none-any.whl.metadata
#   Downloading ffmpy-0.4.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==0.6.1 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for gradio-client==0.6.1 from https://files.pythonhosted.org/packages/7d/04/e1654ee28fb2686514ca8ae31af5e489403964d48764788f9a168e069c0f/gradio_client-0.6.1-py3-none-any.whl.metadata
#   Downloading gradio_client-0.6.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting httpx (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for httpx from https://files.pythonhosted.org/packages/56/95/9377bcb415797e44274b51d46e3249eba641711cf3348050f76ee7b15ffc/httpx-0.27.2-py3-none-any.whl.metadata
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub>=0.14.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for huggingface-hub>=0.14.0 from https://files.pythonhosted.org/packages/d7/4d/017d8d7cff5100092da8ea19139bcb1965bbadcbb5ddd0480e2badc299e8/huggingface_hub-0.26.1-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.26.1-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for importlib-resources<7.0,>=1.3 from https://files.pythonhosted.org/packages/e1/6a/4604f9ae2fa62ef47b9de2fa5ad599589d28c9fd1d335f32759813dfa91e/importlib_resources-6.4.5-py3-none-any.whl.metadata
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting jinja2<4.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for jinja2<4.0 from https://files.pythonhosted.org/packages/31/80/3a54838c3fb461f6fec263ebf3a3a41771bd05190238de3486aae8540c36/jinja2-3.1.4-py3-none-any.whl.metadata
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting markupsafe~=2.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for markupsafe~=2.0 from https://files.pythonhosted.org/packages/97/18/c30da5e7a0e7f4603abfc6780574131221d9148f323752c2755d48abad30/MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: matplotlib~=3.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (3.7.2)
# Requirement already satisfied: numpy~=1.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (1.23.5)
# Collecting orjson~=3.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for orjson~=3.0 from https://files.pythonhosted.org/packages/8a/1e/b3abbe352f648f96a418acd1e602b1c77ffcc60cf801a57033da990b2c49/orjson-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading orjson-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/50.6 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (9.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,<3.0.0,>=1.7.4 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (1.10.6)
# Collecting pydub (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for pydub from https://files.pythonhosted.org/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl.metadata
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for python-multipart from https://files.pythonhosted.org/packages/f5/0b/c316262244abea7481f95f1e91d7575f3dfcf6455d56d1ffe9839c582eb1/python_multipart-0.0.12-py3-none-any.whl.metadata
#   Downloading python_multipart-0.0.12-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (6.0)
# Requirement already satisfied: requests~=2.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (2.31.0)
# Collecting semantic-version~=2.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for semantic-version~=2.0 from https://files.pythonhosted.org/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl.metadata
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /databricks/python3/lib/python3.11/site-packages (from gradio==3.50.2->dbtunnel[gradio]) (4.10.0)
# Collecting uvicorn>=0.14.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for uvicorn>=0.14.0 from https://files.pythonhosted.org/packages/eb/14/78bd0e95dd2444b6caacbca2b730671d4295ccb628ef58b81bee903629df/uvicorn-0.32.0-py3-none-any.whl.metadata
#   Downloading uvicorn-0.32.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting websockets<12.0,>=10.0 (from gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for websockets<12.0,>=10.0 from https://files.pythonhosted.org/packages/a9/5e/b25c60067d700e811dccb4e3c318eeadd3a19d8b3620de9f97434af777a7/websockets-11.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading websockets-11.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting fsspec (from gradio-client==0.6.1->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for fsspec from https://files.pythonhosted.org/packages/c6/b2/454d6e7f0158951d8a78c2e1eb4f69ae81beb8dca5fee9809c6c99e9d0d0/fsspec-2024.10.0-py3-none-any.whl.metadata
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp)
#   Obtaining dependency information for aiohappyeyeballs>=2.3.0 from https://files.pythonhosted.org/packages/f7/d8/120cd0fe3e8530df0539e71ba9683eade12cae103dd7543e50d15f737917/aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp)
#   Obtaining dependency information for aiosignal>=1.1.2 from https://files.pythonhosted.org/packages/76/ac/a7305707cb852b7e16ff80eaf5692309bde30e2b1100a1fcacdc8f731d97/aiosignal-1.3.1-py3-none-any.whl.metadata
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp)
#   Obtaining dependency information for attrs>=17.3.0 from https://files.pythonhosted.org/packages/6a/21/5b6702a7f963e95456c0de2d495f67bf5fd62840ac655dc451586d23d39a/attrs-24.2.0-py3-none-any.whl.metadata
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/b3/c9/0bc5ee7e1f5cc7358ab67da0b7dfe60fbd05c254cea5c6108e7d1ae28c63/frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp)
#   Obtaining dependency information for multidict<7.0,>=4.5 from https://files.pythonhosted.org/packages/ba/af/73d13b918071ff9b2205fcf773d316e0f8fefb4ec65354bbcf0b10908cc6/multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting yarl<2.0,>=1.12.0 (from aiohttp)
#   Obtaining dependency information for yarl<2.0,>=1.12.0 from https://files.pythonhosted.org/packages/e2/13/b6eff6ea1667aee948ecd6b1c8fb6473234f8e48f49af97be93251869c51/yarl-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading yarl-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/63.7 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.11/site-packages (from databricks-sdk>=0.18.0->dbtunnel[gradio]) (2.31.0)
# Requirement already satisfied: idna>=2.0 in /databricks/python3/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp) (3.4)
# Collecting propcache>=0.2.0 (from yarl<2.0,>=1.12.0->aiohttp)
#   Obtaining dependency information for propcache>=0.2.0 from https://files.pythonhosted.org/packages/8c/56/98c2054c8526331a05f205bf45cbb2cda4e58e56df70e76d6a509e5d6ec6/propcache-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading propcache-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting jsonschema>=3.0 (from altair<6.0,>=4.2.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for jsonschema>=3.0 from https://files.pythonhosted.org/packages/69/4a/4f9dbeb84e8850557c02365a0eee0649abe5eb1d84af92a25731c6c0f922/jsonschema-4.23.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting narwhals>=1.5.2 (from altair<6.0,>=4.2.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for narwhals>=1.5.2 from https://files.pythonhosted.org/packages/82/45/6bb08a5e5ac2d9a95f4116567d0aafb1e5f86c4bbcf982e209e5ae872b3d/narwhals-1.10.0-py3-none-any.whl.metadata
#   Downloading narwhals-1.10.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk>=0.18.0->dbtunnel[gradio]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk>=0.18.0->dbtunnel[gradio]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk>=0.18.0->dbtunnel[gradio]) (4.9)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.11/site-packages (from huggingface-hub>=0.14.0->gradio==3.50.2->dbtunnel[gradio]) (3.13.4)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.14.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for tqdm>=4.42.1 from https://files.pythonhosted.org/packages/48/5d/acf5905c36149bbaec41ccf7f2b68814647347b72075ac0b1fe3022fdc73/tqdm-4.66.5-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/57.6 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio==3.50.2->dbtunnel[gradio]) (2022.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests~=2.0->gradio==3.50.2->dbtunnel[gradio]) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests~=2.0->gradio==3.50.2->dbtunnel[gradio]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests~=2.0->gradio==3.50.2->dbtunnel[gradio]) (2023.7.22)
# Requirement already satisfied: click>=7.0 in /databricks/python3/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio==3.50.2->dbtunnel[gradio]) (8.0.4)
# Collecting h11>=0.8 (from uvicorn>=0.14.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for h11>=0.8 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for starlette<0.42.0,>=0.40.0 from https://files.pythonhosted.org/packages/35/c6/a4443bfabf5629129512ca0e07866c4c3c094079ba4e9b2551006927253c/starlette-0.41.0-py3-none-any.whl.metadata
#   Downloading starlette-0.41.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting anyio (from httpx->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for anyio from https://files.pythonhosted.org/packages/e4/f5/f2b75d2fc6f1a260f340f0e7c6a060f4dd2961cc16884ed851b0d18da06a/anyio-4.6.2.post1-py3-none-any.whl.metadata
#   Downloading anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# Collecting httpcore==1.* (from httpx->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/06/89/b161908e2f51be56568184aeb4a880fd287178d176fd1c860d2217f41106/httpcore-1.0.6-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.6-py3-none-any.whl.metadata (21 kB)
# Collecting sniffio (from httpx->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for sniffio from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/d1/0f/8910b19ac0670a0f80ce1008e5e751c4a57e14d2c4c13a482aa6079fa9d6/jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/b7/59/2056f61236782a2c86b33906c025d4f4a0b17be0161b63b70fd9e8775d36/referencing-0.35.1-py3-none-any.whl.metadata
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.50.2->dbtunnel[gradio])
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/a7/e8/85835077b782555d6b3416874b702ea6ebd7db1f145283c9252968670dd5/rpds_py-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading rpds_py-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk>=0.18.0->dbtunnel[gradio]) (0.4.8)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==3.50.2->dbtunnel[gradio]) (1.16.0)
# Downloading gradio-3.50.2-py3-none-any.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/20.3 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/20.3 MB 219.0 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━ 10.0/20.3 MB 147.5 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 14.9/20.3 MB 124.9 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.3/20.3 MB 175.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.3/20.3 MB 175.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 20.3/20.3 MB 175.6 MB/s eta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 69.7 MB/s eta 0:00:00
# Downloading gradio_client-0.6.1-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/299.2 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 34.6 MB/s eta 0:00:00
# Downloading aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.3 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.0 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/63.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 9.6 MB/s eta 0:00:00
# Downloading frozenlist-1.4.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/272.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.3/272.3 kB 30.9 MB/s eta 0:00:00
# Downloading multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/129.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 21.8 MB/s eta 0:00:00
# Downloading yarl-1.16.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (342 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/342.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.8/342.8 kB 43.3 MB/s eta 0:00:00
# Downloading dbtunnel-0.16.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/54.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.6 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading altair-5.4.1-py3-none-any.whl (658 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/658.1 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 61.1 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.1-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/447.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.4/447.4 kB 48.3 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/133.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 20.4 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading orjson-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/144.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.5/144.5 kB 19.1 MB/s eta 0:00:00
# Downloading propcache-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/236.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 35.9 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/63.7 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 10.3 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/130.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 7.8 MB/s eta 0:00:00
# Downloading fastapi-0.115.3-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/94.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 kB 11.1 MB/s eta 0:00:00
# Downloading ffmpy-0.4.0-py3-none-any.whl (5.8 kB)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/76.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 13.1 MB/s eta 0:00:00
# Downloading httpcore-1.0.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.0 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 9.6 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.12-py3-none-any.whl (23 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/179.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 22.3 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/58.3 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/88.5 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 12.6 MB/s eta 0:00:00
# Downloading narwhals-1.10.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/193.6 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 26.3 MB/s eta 0:00:00
# Downloading starlette-0.41.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/73.2 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 12.6 MB/s eta 0:00:00
# Downloading anyio-4.6.2.post1-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/90.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 13.0 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/78.4 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 12.8 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (354 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/354.8 kB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.8/354.8 kB 44.0 MB/s eta 0:00:00
# Installing collected packages: pydub, websockets, tqdm, sniffio, semantic-version, rpds-py, python-multipart, propcache, orjson, narwhals, multidict, markupsafe, importlib-resources, h11, fsspec, frozenlist, ffmpy, attrs, aiohappyeyeballs, aiofiles, yarl, uvicorn, referencing, jinja2, huggingface-hub, httpcore, anyio, aiosignal, starlette, jsonschema-specifications, httpx, aiohttp, jsonschema, gradio-client, fastapi, dbtunnel, altair, gradio
# Successfully installed aiofiles-23.2.1 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiosignal-1.3.1 altair-5.4.1 anyio-4.6.2.post1 attrs-24.2.0 dbtunnel-0.16.0 fastapi-0.115.3 ffmpy-0.4.0 frozenlist-1.4.1 fsspec-2024.10.0 gradio-3.50.2 gradio-client-0.6.1 h11-0.14.0 httpcore-1.0.6 httpx-0.27.2 huggingface-hub-0.26.1 importlib-resources-6.4.5 jinja2-3.1.4 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 markupsafe-2.1.5 multidict-6.1.0 narwhals-1.10.0 orjson-3.10.10 propcache-0.2.0 pydub-0.25.1 python-multipart-0.0.12 referencing-0.35.1 rpds-py-0.20.0 semantic-version-2.10.0 sniffio-1.3.1 starlette-0.41.0 tqdm-4.66.5 uvicorn-0.32.0 websockets-11.0.3 yarl-1.16.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
import os
os.environ['DATABRICKS_TOKEN'] = dbutils.secrets.get("hackathon-databricks", "hackathon-databricks")

os.environ['API_ENDPOINT'] = "https://adb-109982197220035.15.azuredatabricks.net/serving-endpoints/insurance_model/invocations"

# %%
import itertools
import gradio as gr
import requests
import json
import os  # Added import for os environment variable

def respond(message, history):
    if len(message.strip()) == 0:
        return "ERROR: the question should not be empty"

    print("#### Message #####")
    print(message)

    local_token = os.getenv('DATABRICKS_TOKEN')
    local_endpoint = os.getenv('API_ENDPOINT')

    if local_token is None or local_endpoint is None:
        return "ERROR: missing env variables"

    # Add your API token to the headers
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {local_token}'
    }

    payload = {
        "inputs": [message]
    }

    try:
        response = requests.post(
            local_endpoint, json=payload, headers=headers, timeout=100)

        response_json = response.json()
        print("#### RESPONSE JSON")
        print(response_json)

        response_data = response_json["predictions"][0]  # Updated line to extract the result field
        print(response_data)

    except Exception as error:
        response_data = f"ERROR: status_code: {type(error).__name__}"

    return response_data

# Customize the theme using predefined color shortcuts
theme = gr.themes.Soft()

demo = gr.ChatInterface(
    respond,
    chatbot=gr.Chatbot(
        show_label=False, 
        container=False, 
        show_copy_button=True, 
        bubble_full_width=True,
        height=600  # Increased height of the chatbox
    ),
    textbox=gr.Textbox(
        placeholder="Ask me a question", 
        container=False, 
        scale=10,  # Increased the scale for a larger input area
        elem_id="dynamic-textbox"  # ID for dynamic resizing
    ),
    title="Team REV-Engers - Insurance Comparison AI",
    description="Insurance model created with Databricks AutoML for Databricks Hackathon",
    examples=[
        ["Given the property's age, size, and location, what would the estimated insurance premium be based on historical data for similar assets?"],
    ],
    cache_examples=False,
    theme=theme,
    retry_btn=None,
    undo_btn=None,
    clear_btn="Clear",
)

# %%
from dbtunnel import dbtunnel
dbtunnel.gradio(demo).run()
# Out:
# [2024-10-23T03:57:54+0000] [INFO] {gradio.py:_run_app:71} - Starting server...
# [2024-10-23T03:57:54+0000] [INFO] {gradio.py:_run_app:92} - Use this link:
# https://adb-dp-109982197220035.15.azuredatabricks.net/driver-proxy/o/109982197220035/0926-161329-nh1mzkhl/8080/
# INFO:     Started server process [1748]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8080 (Press CTRL+C to quit)
# INFO:     10.105.4.10:43066 - "GET / HTTP/1.1" 200 OK
# INFO:     10.105.4.10:43070 - "GET /assets/index-a959df42.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40010 - "GET /assets/index-5ac12191.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40020 - "GET /info HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40032 - "GET /assets/Blocks-0733f3b3.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40042 - "GET /assets/Blocks-14eb0294.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40044 - "GET /assets/Button-fb0eed2f.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40054 - "GET /assets/Button-dd3ccceb.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40064 - "GET /theme.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40076 - "GET /assets/index-a5fdef40.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40090 - "GET /assets/index-37519934.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40098 - "GET /assets/StaticMarkdown-06312fb7.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40102 - "GET /assets/StaticColumn-2853eb31.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40116 - "GET /assets/StaticColumn-e8db0143.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40132 - "GET /assets/index-2c0d26e2.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40144 - "GET /assets/index-5a99b9f7.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40160 - "GET /assets/dsv-576afacd.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40176 - "GET /assets/Info-91922efa.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40178 - "GET /assets/StaticMarkdown-1e08a987.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40192 - "GET /assets/BlockLabel-5f053d92.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40204 - "GET /assets/index-aaf62f38.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40224 - "GET /assets/Copy-76383fd2.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40218 - "GET /assets/index-2f00b72c.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40236 - "GET /assets/IconButton-a920ab53.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40246 - "GET /assets/index-e5090eed.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40254 - "GET /assets/ShareButton-cdf33464.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40268 - "GET /assets/Player-afca2092.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40256 - "GET /assets/index-8d377615.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40282 - "GET /assets/index-e75b4bc3.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40286 - "GET /assets/csv-b0b7514a.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40292 - "GET /assets/index-4594c4cd.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40296 - "GET /assets/index-d1f7186e.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40304 - "GET /assets/BlockTitle-a5d1fe95.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40310 - "GET /assets/file-url-43c83f6d.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40322 - "GET /assets/InteractiveTextbox-8c4d1407.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40336 - "GET /assets/index-08631e7e.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40348 - "GET /assets/StaticForm-3812b7f1.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40356 - "GET /assets/index-6bb91bb9.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40368 - "GET /assets/index-93c91554.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40378 - "GET /assets/Player.svelte_svelte_type_style_lang-5ec8ba35.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40384 - "GET /assets/Textbox-dde6f8cc.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40390 - "GET /assets/index-33bad8d4.css HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40396 - "GET /assets/StaticForm-0d359fd6.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40402 - "GET /assets/api-logo-5346f193.svg HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40418 - "GET /assets/logo-0a070fcf.svg HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40434 - "GET /assets/utils-c3e3db58.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40436 - "GET /assets/Textbox-8e45e7cb.js HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40442 - "POST /run/predict HTTP/1.1" 200 OK
# INFO:     10.105.4.10:40444 - "POST /run/predict HTTP/1.1" 200 OK
# #### Message #####
# hello
